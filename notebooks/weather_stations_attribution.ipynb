# %% [markdown]
# #### Weather station attribution
#
# We will limit the number of weather stations to be used for each route to the up to 10 closest within a 20km radius

# %%
from willthisfreeze.datapreparation.utils import bounding_box
from willthisfreeze.dbutils import load_routes, read_config, get_engine

conf = read_config()
engine =  get_engine(conf)   

routes = load_routes(engine=engine)

print(next(routes).lat)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from willthisfreeze.datapreparation.utils import bounding_box
#       2 from willthisfreeze.dbutils import load_routes, read_config, get_engine
#       4 conf = read_config()
#
# ModuleNotFoundError: No module named 'willthisfreeze'
